# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import seaborn as sns
# %matplotlib inline

import bs4 as bs
import urllib
import urllib.request

import io
import re
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn import metrics

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## I+D 1: Locals

# %%
df22 = pd.read_csv('Quiniela_2122.csv')

df21 = pd.read_csv('Quiniela_2021.csv')
df20 = pd.read_csv('Quiniela_1920.csv')
df19 = pd.read_csv('Quiniela_1819.csv')
df18 = pd.read_csv('Quiniela_1718.csv')
df17 = pd.read_csv('Quiniela_1617.csv')
df16 = pd.read_csv('Quiniela_1516.csv')

# %%
SEASONS = [df21, df20, df19, df18, df17, df16]

aciertos = 0;
totalMoney = 0;

for season in SEASONS:
    for ii, row in season.iterrows():
        if((ii%14) == 0):
            #print(aciertos)

            if aciertos == 10:
                totalMoney += row['premio_10']
                print("10 aciertos: ", row['premio_10'], "€")
            elif aciertos == 11:
                totalMoney += row['premio_11']
                print("11 aciertos: ", row['premio_11'], "€")
            elif aciertos == 12:
                totalMoney += row['premio_12']
                print("12 aciertos: ", row['premio_12'], "€")
            elif aciertos == 13:
                totalMoney += row['premio_13']
                print("13 aciertos: ", row['premio_13'], "€")
            elif aciertos == 14:
                totalMoney += row['premio_14']
                print("14 aciertos: ", row['premio_14'], "€")
            else:
                totalMoney -= 1

            aciertos = 0;
            
        
        if(row['resultado'] == '1'):
            aciertos += 1;     
    print(row['Season'], "totalMoney: ", totalMoney)
    totalMoney = 0
# Out:
# 10 aciertos:  0 €
# TEMPORADA 20/21 totalMoney:  -57
# 10 aciertos:  39 €
# 12 aciertos:  549 €
# TEMPORADA 19/20 totalMoney:  532
# 11 aciertos:  43 €
# 11 aciertos:  105 €
# 10 aciertos:  7 €
# TEMPORADA 18/19 totalMoney:  100
# 10 aciertos:  1 €
# 11 aciertos:  3 €
# TEMPORADA 17/18 totalMoney:  -52
# 10 aciertos:  1 €
# 10 aciertos:  2 €
# 10 aciertos:  6 €
# 10 aciertos:  15 €
# 11 aciertos:  89 €
# TEMPORADA 16/17 totalMoney:  60
# 10 aciertos:  6 €
# 10 aciertos:  2 €
# 10 aciertos:  57 €
# 10 aciertos:  2 €
# TEMPORADA 15/16 totalMoney:  13

# %%
SEASONS = [df21, df20, df19, df18, df17, df16]

aciertos = 0;
totalMoney = 0;

for season in SEASONS:
    for ii, row in season.iterrows():
        if((ii%14) == 0):
            #print(aciertos)

            if aciertos == 10:
                totalMoney += row['premio_10']
                print("10 aciertos: ", row['premio_10'], "€")
            elif aciertos == 11:
                totalMoney += row['premio_11']
                print("11 aciertos: ", row['premio_11'], "€")
            elif aciertos == 12:
                totalMoney += row['premio_12']
                print("12 aciertos: ", row['premio_12'], "€")
            elif aciertos == 13:
                totalMoney += row['premio_13']
                print("13 aciertos: ", row['premio_13'], "€")
            elif aciertos == 14:
                totalMoney += row['premio_14']
                print("14 aciertos: ", row['premio_14'], "€")
            else:
                totalMoney -= 12288

            aciertos = 0;
            
        
        if(row['resultado'] == '1' or row['resultado'] == '2'):
            aciertos += 1;     
    print(row['Season'], "totalMoney: ", totalMoney)
    totalMoney = 0
# Out:
# 10 aciertos:  16 €
# 10 aciertos:  6 €
# 10 aciertos:  11 €
# 13 aciertos:  43204 €
# 11 aciertos:  13 €
# 10 aciertos:  7 €
# 11 aciertos:  194 €
# 11 aciertos:  0 €
# 10 aciertos:  2 €
# 12 aciertos:  39 €
# 12 aciertos:  14 €
# 12 aciertos:  203 €
# 14 aciertos:  246489 €
# 10 aciertos:  2 €
# 12 aciertos:  460 €
# 10 aciertos:  0 €
# 11 aciertos:  18 €
# 10 aciertos:  8 €
# 11 aciertos:  8 €
# 10 aciertos:  9 €
# 12 aciertos:  185 €
# 12 aciertos:  564 €
# 10 aciertos:  4 €
# 10 aciertos:  0 €
# 12 aciertos:  5070 €
# 11 aciertos:  13 €
# 12 aciertos:  21 €
# 13 aciertos:  1126 €
# 10 aciertos:  3 €
# 10 aciertos:  25 €
# 11 aciertos:  0 €
# 13 aciertos:  2542 €
# 11 aciertos:  225 €
# 10 aciertos:  9 €
# 10 aciertos:  1 €
# 11 aciertos:  127 €
# 11 aciertos:  4 €
# 13 aciertos:  49 €
# 11 aciertos:  3 €
# 11 aciertos:  1 €
# 12 aciertos:  513 €
# 11 aciertos:  37 €
# 10 aciertos:  6 €
# 10 aciertos:  6 €
# TEMPORADA 20/21 totalMoney:  129205
# 11 aciertos:  111 €
# ...
